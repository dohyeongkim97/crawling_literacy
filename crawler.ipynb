# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
import time
from scipy.stats import norm

# %%
# baseline https

# weekly
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2024&Month=12&Week=2&BestType=Bestseller&SearchSubBarcode=

# monthly 
# https://www.aladin.co.kr/shop/common/wbest.aspx?BranchType=1&CID=0&Year=2005&Month=12&Week=3&BestType=MonthlyBest&SearchSubBarcode=

# yearly
# https://www.aladin.co.kr/shop/common/wbest.aspx?BestType=YearlyBest&BranchType=1&CID=0&Year=2022

# %%
def scraper(year, page, month = None, week = None):
    if (not week) & (not month):
        BestType = 'YearlyBest'
        cnt = 300

    elif week and month: # when in case weekly
        BestType = 'Bestseller'
        cnt = 1000

    elif month & (not week): # when in case monthly
        BestType = 'MonthlyBest'
        cnd = 1000
        week = 3

    params = {
        'BestType': BestType,
        'BranchType': 1,
        'CID': 0,
        'Year': year,
        'Month': month,
        'Week': week,
        'page': page,
        'cnt': cnt,
        'SortOrder': 1
    }

    base_url = 'https://www.aladin.co.kr/shop/common/wbest.aspx?'

    if BestType == 'YearlyBest':
        url_target = f"{base_url}BestType={params['BestType']}&BranchType={params['BranchType']}&CID={params['CID']}&Year={params['Year']}&Month={params['Month']}&Week={params['Week']}&page={params['page']}&cnt={params['cnt']}&SortOrder={params['SortOrder']}"

    elif BestType == 'Bestseller':
        url_target = f"{base_url}BestType={params['BestType']}&BranchType={params['BranchType']}&CID={params['CID']}&Year={params['Year']}&Month={params['Month']}&Week={params['Week']}&page={params['page']}&cnt={params['cnt']}&SortOrder={params['SortOrder']}"

    elif BestType == 'MonthlyBest':
        url_target = f"{base_url}BestType={params['BestType']}&BranchType={params['BranchType']}&CID={params['CID']}&Year={params['Year']}&Month={params['Month']}&Week={params['Week']}&page={params['page']}&cnt={params['cnt']}&SortOrder={params['SortOrder']}"


    response = requests.get(url_target)

    return response.text

# %%
mean = 0.6
std_dev = 0.1

norm(loc = mean, scale = std_dev)

def time_norm(norm):
    value = norm.rvs()
    while value < 0.35:
        value = norm.rvs()
    return value

# %%
year_2020 = pd.read_csv("yearly_df_2020.csv")
week_2020 = pd.read_csv("week_df_2020.csv")

# %%
week_2020
# Out:
#            0  1  2                                                 3  \
# 0       2010  1  1                                            1Q84 1
# 1       2010  1  1                                            1Q84 2
# 2       2010  1  1                            노무현 대통령과 함께하는 2010년 달력
# 3       2010  1  1                                       박철범의 하루 공부법
# 4       2010  1  1                                           엄마를 부탁해
# ...      ... .. ..                                               ...
# 204041  2021  1  5  2021 해커스공기업 단기 합격 NCS 통합 기본서 직업기초능력평가 + 직무수행능력평가
# 204042  2021  1  5              ETS 토익 정기시험 기출문제집 1000 Vol.1 Reading
# 204043  2021  1  5                                     위기의 시대, 돈의 미래
# 204044  2021  1  5                                         목적이 이끄는 삶
# 204045  2021  1  5                                         프롤레타리아의 밤
#
#                                                         4
# 0       https://www.aladin.co.kr/shop/wproduct.aspx?It...
# ...

# %%
week_2024
# Out:
#        Unnamed: 0  year  month  week                            title  \
# 0               0  2021      1     1                       달러구트 꿈 백화점
# 1               1  2021      1     1                         공정하다는 착각
# 2               2  2021      1     1              해커스 토익 기출 VOCA (보카)
# 3               3  2021      1     1                         하이큐!! 45
# 4               4  2021      1     1        시선으로부터, (10만 부 기념 새해 에디션)
# ...           ...   ...    ...   ...                              ...
# 81058       81058  2024     12     3                사랑과 멸종을 바꿔 읽어보십시오
# 81059       81059  2024     12     3  2025 이기적 컴퓨터활용능력 2급 필기 + 실기 올인원
# 81060       81060  2024     12     3                         마법천자문 64
# 81061       81061  2024     12     3           동물농장 (오리지널 초판본 표지 디자인)
# 81062       81062  2024     12     3                              면도날
#
#                                                     link
# 0      https://www.aladin.co.kr/shop/wproduct.aspx?It...
# ...

# %%
month_2020 = pd.read_csv('month_df_2020.csv')
month_2024 = pd.read_csv("month_df_2024.csv")

year_2020 = pd.read_csv("yearly_df_2020.csv")
year_2024 = pd.read_csv("year_df_2024.csv")

week_2020 = pd.read_csv("week_df_2020.csv")
week_2024 = pd.read_csv("week_df_2024.csv")

# %%
year_2024.drop(columns = ['Unnamed: 0'], inplace=True)
year_2020.columns = ['year', 'title', 'link']
year_df = pd.concat([year_2020, year_2024], axis=0)
year_df.reset_index(inplace=True)
week_2020.columns = ['year', 'month', 'week', 'title', 'link']
week_2024.drop(columns = 'Unnamed: 0', inplace=True)
week_df = pd.concat([week_2020, week_2024], axis=0)
week_df.reset_index(inplace=True, drop=True)

# %%
year_df.drop(columns = 'index', inplace=True)

# %%
def scraper_category(soup):
    soup2 = soup.select('#ulCategory a')
    soup2 = str(soup2)
    soup3 = BeautifulSoup(soup2, 'html.parser')
    temp_list = []
    temp = soup3.find_all('a')
    soup3.find_all('a')
    j = 0
    lists_of_theme = []
    for i in soup3.find_all('a'):
        if len(lists_of_theme) < 6:

            if i.text in ['국내도서']:
                j = 0
                j = 1
            elif i.text != '접기':
                if j in [1, 2]:
                    lists_of_theme.append(i.text)
                    j += 1
                else:
                    j += 1
        else:
            break

    targets_conts = soup.find('div', class_='conts_info_list1')
    for i in targets_conts.find_all('li'):
        try:
            if '쪽' in i.text:
                pages = int(i.text[:-1])
                break
        except:
            pages = 0
    
    return lists_of_theme, pages

# %%
df_cols = ['title', 'address', 'pages', 'tag1', 'tag2', 'tag3', 'tag4', 'tag5', 'tag6']

# %%
infos_df = pd.DataFrame(columns = df_cols)

# %%
total_df = pd.concat([week_df, year_df], axis=0)

# %%
week_df.to_csv("week.csv")
year_df.to_csv("year.csv")

total_df.to_csv('total.csv')

# %%
week_df = pd.read_csv("week.csv")
year_df = pd.read_csv("year.csv")

# %%
titles_uniques = list(set(week_df.title.unique())|set(year_df.title.unique()))

# %%
infos_df[['title', 'address']] = total_df[total_df['title'].isin(titles_uniques)][['title', 'link']].drop_duplicates()

# %%
infos_df = infos_df.reset_index(drop=True)

# %%
print(infos_df.head(5).to_markdown())
# Out:
# |    | title                                | address                                                    |   pages |   tag1 |   tag2 |   tag3 |   tag4 |   tag5 |   tag6 |
# |---:|:-------------------------------------|:-----------------------------------------------------------|--------:|-------:|-------:|-------:|-------:|-------:|-------:|
# |  0 | 1Q84 1                               | https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=4342463 |     nan |    nan |    nan |    nan |    nan |    nan |    nan |
# |  1 | 1Q84 2                               | https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=4342497 |     nan |    nan |    nan |    nan |    nan |    nan |    nan |
# |  2 | 노무현 대통령과 함께하는 2010년 달력 | https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=5872306 |     nan |    nan |    nan |    nan |    nan |    nan |    nan |
# ...

# %%
infos_df_temp = infos_df.copy()

# %%
len(infos_df_temp)
# Out:
# 45742

# %%
for i in range(16000, 20000):
    try:
        soup = BeautifulSoup(requests.get(infos_df_temp.loc[i, 'address']).text, 'html.parser')

        tags, pages = scraper_category(soup)

        for tag in range(len(tags)):
            infos_df_temp.iloc[i, tag+3] = tags[tag]

        infos_df_temp.loc[i, 'pages'] = pages

        print(i)
        time.sleep(norm(loc = 0.5, scale = 0.2).rvs())

        if i % 1000 == 0:
            infos_df_temp.to_csv('infos_df_temp.csv')
            
            files.download('infos_df_temp.csv')
            print(f'{i} saved')

    except:
        print('error occured')
        continue
# Out:
# 16000
# error occured
# 16001
# 16002
# 16003
# 16004
# 16005
# 16006
# 16007
# 16008
# 16009
# 16010
# 16011
# 16012
# 16013
# 16014
# error occured
# error occured
# 16017
# 16018
# 16019
# 16020
# 16021
# error occured
# 16023
# 16024
# 16025
# 16026
# 16027
# error occured
# 16029
# 16030
# 16031
# 16032
# 16033
# 16034
# 16035
# error occured
# 16037
# 16038
# 16039
# 16040
# 16041
# 16042
# 16043
# 16044
# 16045
# 16046
# 16047
# 16048
# 16049
# 16050
# 16051
# 16052
# error occured
# 16053
# error occured
# 16055
# 16056
# error occured
# 16058
# 16059
# error occured
# 16061
# 16062
# 16063
# 16064
# 16065
# 16066
# 16067
# 16068
# 16069
# 16070
# 16071
# 16072
# 16073
# error occured
# error occured
# 16076
# 16077
# 16078
# 16079
# 16080
# 16081
# error occured
# 16083
# 16084
# 16085
# 16086
# error occured
# 16088
# 16089
# 16090
# 16091
# 16092
# 16093
# 16094
# 16095
# 16096
# 16097
# 16098
# 16099
# 16100
# 16101
# 16102
# 16103
# 16104
# 16105
# 16106
# 16107
# 16108
# ...

# %%
infos_df_temp[16000:20000].to_csv("infos_temp_16k_20k.csv")

# %%
infos_df_temp[30000:len(infos_df_temp)].to_csv("infos_temp_30k_fin.csv")

# %%
infos_df_temp.isnull().sum()
# Out:
# title          0
# address        0
# pages      20743
# tag1       20807
# tag2       20807
# tag3       32750
# tag4       32750
# tag5       39826
# tag6       39826
# dtype: int64

# %%
infos_df_temp[20000:30000].to_csv("infos_temp_20k_30k.csv")

# %%
infos_16k = pd.read_csv("infos_df_temp_16k.csv")

# %%
infos_20k = pd.read_csv("infos_temp_16k_20k.csv")

# %%
infos_30k = pd.read_csv("infos_temp_20k_30k.csv")
infos_fin = pd.read_csv("infos_temp_30k_fin.csv")

# %%
infos_fin
# Out:
#        Unnamed: 0                   title  \
# 0           30000   BTS 액자 직소퍼즐 108피스 : 뷔
# 1           30001  BTS 액자 직소퍼즐 108피스 : 슈가
# 2           30002   BTS 액자 직소퍼즐 108피스 : 진
# 3           30003                배지윤 누리해설
# 4           30004  BTS 액자 직소퍼즐 108피스 : RM
# ...           ...                     ...
# 15737       45737                  에그박사 9
# 15738       45738          흔한남매의 흔한 호기심 8
# 15739       45739                천하제일 치킨쇼
# 15740       45740        이상한 과자 가게 전천당 18
# 15741       45741  채사장의 지대넓얕 6 : 성장 VS 분배
#
#                                                  address  pages     tag1  \
# 0      https://www.aladin.co.kr/shop/wproduct.aspx?It...    1.0       만화
# 1      https://www.aladin.co.kr/shop/wproduct.aspx?It...    1.0       만화
# 2      https://www.aladin.co.kr/shop/wproduct.aspx?It...    1.0       만화
# 3      https://www.aladin.co.kr/shop/wproduct.aspx?It...  308.0  수험서/자격증
# 4      https://www.aladin.co.kr/shop/wproduct.aspx?It...    1.0       만화
# ...

# %%
df_info = pd.concat([infos_16k[:16000], infos_20k, infos_30k, infos_fin], axis=0)

# %%
df_info.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
df_info.reset_index(inplace=True, drop=True)

# %%
info = pd.read_csv("info.csv")

# %%
print(info.head(5).to_markdown())
# Out:
# |    |   Unnamed: 0 | title                                | address                                                    |   pages | tag1         | tag2                | tag3         | tag4                       | tag5     | tag6                       |
# |---:|-------------:|:-------------------------------------|:-----------------------------------------------------------|--------:|:-------------|:--------------------|:-------------|:---------------------------|:---------|:---------------------------|
# |  0 |            0 | 1Q84 1                               | https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=4342463 |     656 | 소설/시/희곡 | 일본소설            | 소설/시/희곡 | 세계의 문학                | 추천도서 | 알라딘 독자 선정 올해의 책 |
# |  1 |            1 | 1Q84 2                               | https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=4342497 |     597 | 소설/시/희곡 | 일본소설            | 소설/시/희곡 | 세계의 문학                | 추천도서 | 알라딘 독자 선정 올해의 책 |
# ...

# %%
df_info
# Out:
#                         title  \
# 0                      1Q84 1
# 1                      1Q84 2
# 2      노무현 대통령과 함께하는 2010년 달력
# 3                 박철범의 하루 공부법
# 4                     엄마를 부탁해
# ...                       ...
# 45737                  에그박사 9
# 45738          흔한남매의 흔한 호기심 8
# 45739                천하제일 치킨쇼
# 45740        이상한 과자 가게 전천당 18
# 45741  채사장의 지대넓얕 6 : 성장 VS 분배
#
#                                                  address  pages     tag1  \
# 0      https://www.aladin.co.kr/shop/wproduct.aspx?It...  656.0  소설/시/희곡
# 1      https://www.aladin.co.kr/shop/wproduct.aspx?It...  597.0  소설/시/희곡
# 2      https://www.aladin.co.kr/shop/wproduct.aspx?It...    0.0     사회과학
# 3      https://www.aladin.co.kr/shop/wproduct.aspx?It...  260.0      청소년
# 4      https://www.aladin.co.kr/shop/wproduct.aspx?It...  320.0  소설/시/희곡
# ...                                                  ...    ...      ...
# 45737  https://www.aladin.co.kr/shop/wproduct.aspx?It...  156.0      어린이
# ...

# %%
df_info['tag1'].unique()
# Out:
# array(['소설/시/희곡', '사회과학', '청소년', '좋은부모', '에세이', '인문학', '경제경영', '외국어',
#        '과학', '만화', '자기계발', '예술/대중문화', '종교/역학', '요리/살림', '역사', '건강/취미',
#        '여행', '수험서/자격증', nan, '컴퓨터/모바일', '대학교재/전문서적', '어린이', '고전',
#        '전집/중고전집', '달력/기타', '해외잡지', '유아'], dtype=object)

# %%
df_info.isnull().sum()
# Out:
# title          0
# address        0
# pages       1414
# tag1        1584
# tag2        1585
# tag3       21778
# tag4       21781
# tag5       33706
# tag6       33710
# dtype: int64

# %%
df_info.to_csv("info.csv")
